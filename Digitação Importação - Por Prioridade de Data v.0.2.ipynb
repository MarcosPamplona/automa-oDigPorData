# %%
import datetime
import pyautogui
import pandas as pd

df = pd.read_excel('JUNBO HDS MATRIZ - DIG.xlsx')
display(df)

#Guarda a quantidade de fornecedores, sem repetição
fornecedores = []

#Armazena as quantidades sem os Zeros.
quantidades = []

#Chegada
chegada = []

#CodFornecedor
codFornecedor = []

#Totais Fornecedores
Quantidade_Totais_Fornecedores = []

#CodLoja
codLoja = []

#Urgencia
urgencia = []

#codPorMes = [[],[],[],[],[],[],[],[],[],[],[]]

#Lendo somente a coluna onde estão os fornecedores.
coluna_fornecedor = df.iloc[:, 6]

#Função para ordenar pelo mes
def ordenaMes(lista):
    
    lista1 = [[] for _ in range(12)]  # Lista com 12 sublistas
    meses = ['01/25', '02/25', '03/25', '04/25', '05/25', '06/25', '07/25', '08/25', '09/25', '10/25', '11/25', '12/25']

    # Dicionário para mapear meses aos índices
    mes_index_map = {mes: i for i, mes in enumerate(meses)}

    # Laço para organizar os códigos
    for c in range(len(coluna_quantidades)):
        mes = urgenciaTotalFormatada[c]  # Obtém o mês atual
        if mes in mes_index_map:  # Verifica se o mês está na lista de meses
            lista1[mes_index_map[mes]].append(lista[c])  # Adiciona no índice correto
            
    return lista1


#################################
#LENDO APENAS A COLUNA QUANTIDADE
#################################


# Especificando o nome do arquivo Excel e o nome da Aba da planilha
nome_arquivo = 'JUNBO HDS MATRIZ - DIG.xlsx'
nome_planilha = 'Plan1'

# Especificando o número de linhas a serem ignoradas no início da coluna
# Como na planilha de análise há linhas no inicio que não contém valores devem ser ignoradas
linhas_a_ignorar = 3

# Carregando o arquivo Excel usando o Pandas, pulando as 3 primeiras linhas
dados = pd.read_excel(nome_arquivo, sheet_name=nome_planilha, skiprows=linhas_a_ignorar)

# Selecionando a coluna desejada

coluna_desejada = "Qtd Comprar - Pós Revisão" # Substituir pelo nome coluna

#Armazena a quantidade com os Zeros.
coluna_quantidades = dados[coluna_desejada]



######################################
#TIRANDO OS ZEROS DAS QUANTIDADES LIDAS
######################################


for c in range(len(coluna_quantidades)):
    
    if coluna_quantidades[c] != 0:
        
        quantidades.append(coluna_quantidades[c])


#################################
# LENDO COD FORNECEDOR
#################################

# Especificando o nome do arquivo Excel e o nome da Aba da planilha
nome_arquivo = 'JUNBO HDS MATRIZ - DIG.xlsx'
nome_planilha = 'Plan1'

# Especificando o número de linhas a serem ignoradas no início da coluna
# Como na planilha de análise há linhas no inicio que não contém valores deve ser ignoradas
linhas_a_ignorar = 3

# Carregando o arquivo Excel usando o Pandas, pulando as primeiras linhas
dados = pd.read_excel(nome_arquivo, sheet_name=nome_planilha, skiprows=linhas_a_ignorar)

# Selecionando a coluna desejada
coluna_desejada = "CodFornecedor"  # Substitua 'Nome_da_Coluna' pelo nome da sua coluna


coluna_codFornecedor = dados[coluna_desejada]

codFornecedor_total = []

for c in range(len(coluna_quantidades)):
    
    if coluna_quantidades[c] != 0:
        
        codFornecedor_total.append(int(coluna_codFornecedor[c]))

#################################
#LENDO COD. LOJA
#################################

# Especificando o nome do arquivo Excel e o nome da Aba da planilha
nome_arquivo = 'JUNBO HDS MATRIZ - DIG.xlsx'
nome_planilha = 'Plan1'

# Especificando o número de linhas a serem ignoradas no início da coluna
# Como na planilha de análise há linhas no inicio que não contém valores deve ser ignoradas
linhas_a_ignorar = 3

# Carregando o arquivo Excel usando o Pandas, pulando as primeiras linhas
dados = pd.read_excel(nome_arquivo, sheet_name=nome_planilha, skiprows=linhas_a_ignorar)

# Selecionando a coluna desejada
coluna_desejada = "Loja"  # Substitua 'Nome_da_Coluna' pelo nome da sua coluna


coluna_codLoja = dados[coluna_desejada]

codLoja_total = []

for c in range(len(coluna_quantidades)):
    
    if coluna_quantidades[c] != 0:
        
        codLoja_total.append(int(coluna_codLoja[c]))

#################################        
#LENDO CHEGADA
#################################



# Especificando o nome do arquivo Excel e o nome da Aba da planilha
nome_arquivo = 'JUNBO HDS MATRIZ - DIG.xlsx'
nome_planilha = 'Plan1'

# Especificando o número de linhas a serem ignoradas no início da coluna
# Como na planilha de análise há linhas no inicio que não contém valores deve ser ignoradas
linhas_a_ignorar = 3

# Carregando o arquivo Excel usando o Pandas, pulando as primeiras linhas
dados = pd.read_excel(nome_arquivo, sheet_name=nome_planilha, skiprows=linhas_a_ignorar)

# Selecionando a coluna desejada
coluna_desejada = "Chegada"  # Substitua 'Nome_da_Coluna' pelo nome da sua coluna


coluna_chegada = dados[coluna_desejada]

chegada_total = []


for c in range(len(coluna_quantidades)):
    
    if coluna_quantidades[c] != 0:
        
        chegada_total.append(int(coluna_chegada[c]))              

            
            
######################################       
#LENDO APENAS A COLUNA "FORNECEDOR".
######################################



# Especificando o nome do arquivo Excel e o nome da Aba da planilha
nome_arquivo = 'JUNBO HDS MATRIZ - DIG.xlsx'
nome_planilha = 'Plan1'

# Especificando o número de linhas a serem ignoradas no início da coluna
# Como na planilha de análise há linhas no inicio que não contém valores deve ser ignoradas
linhas_a_ignorar = 3

# Carregando o arquivo Excel usando o Pandas, pulando as primeiras linhas
dados = pd.read_excel(nome_arquivo, sheet_name=nome_planilha, skiprows=linhas_a_ignorar)

# Selecionando a coluna desejada
coluna_desejada = "Fornecedor"  #Substituir 'Nome_da_Coluna' pelo nome da coluna da planilha.

coluna_fornecedor = dados[coluna_desejada]



#Armazenando apenas os fornecedores que possuem quantidades maior que 0 e diferente de Nan e previsão de chegada. sem repetição 


for c in range(len(coluna_quantidades)):
    
    if coluna_quantidades[c] != 0:
        
        if coluna_fornecedor[c] not in fornecedores:
            
            fornecedores.append(coluna_fornecedor[c]) 
            chegada.append(int(coluna_chegada[c]))
            codFornecedor.append(coluna_codFornecedor[c])
            codLoja.append(coluna_codLoja[c])
            
#Armazenando apenas os fornecedores que possuem quantidades maior que 0 e diferente de Nan. com repetições


fornecedores_total = []

for c in range(len(coluna_quantidades)):
    
    if coluna_quantidades[c] != 0:
        
        fornecedores_total.append(coluna_fornecedor[c])


##################################
#LENDO AS DATAS DE URGÊNCIA
##################################        


# Especificando o nome do arquivo Excel e o nome da Aba da planilha
nome_arquivo = 'JUNBO HDS MATRIZ - DIG.xlsx'
nome_planilha = 'Plan1'

# Especificando o número de linhas a serem ignoradas no início da coluna
# Como na planilha de análise há linhas no inicio que não contém valores deve ser ignoradas
linhas_a_ignorar = 3

# Carregando o arquivo Excel usando o Pandas, pulando as primeiras linhas
dados = pd.read_excel(nome_arquivo, sheet_name=nome_planilha, skiprows=linhas_a_ignorar)

# Selecionando a coluna desejada
coluna_desejada = "Urgência" # Substitua 'Nome_da_Coluna' pelo nome da sua coluna


coluna_urgencia = dados[coluna_desejada]

urgencia_total = []

for c in range(len(coluna_quantidades)):
    
    if coluna_quantidades[c] != 0:
        
        urgencia_total.append(coluna_urgencia[c])
        
urgenciaTotalFormatada = [timestamp.date().strftime("%m/%y") for timestamp in urgencia_total]
        
        
        
##################################
#LENDO OS CÓDIGOS
##################################


# Especificando o nome do arquivo Excel e o nome da Aba da planilha
nome_arquivo = 'JUNBO HDS MATRIZ - DIG.xlsx' 
nome_planilha = 'Plan1'

# Especificando o número de linhas a serem ignoradas no início da coluna
# Como na planilha de análise há linhas no inicio que não contém valores deve ser ignoradas
linhas_a_ignorar = 3

# Carregando o arquivo Excel usando o Pandas, pulando as primeiras linhas
dados = pd.read_excel(nome_arquivo, sheet_name=nome_planilha, skiprows=linhas_a_ignorar)

# Selecionando a coluna desejada
coluna_desejada = "Referência"  # Substitua 'Nome_da_Coluna' pelo nome da sua coluna


coluna_codigos = dados[coluna_desejada]

codigos_total = []

for c in range(len(coluna_quantidades)):
    
    if coluna_quantidades[c] != 0:
        
        codigos_total.append(coluna_codigos[c])
        
        
###############################        
# SEPARANDO OS DADOS POR MES: #
###############################


quantidadeMes = ordenaMes(quantidades)
codPorMes = ordenaMes(codigos_total)
codFornecedorMes = ordenaMes(codFornecedor_total)
codLojaMes = ordenaMes(codLoja_total) 
codChegadaMes = ordenaMes(chegada_total)
nomeFornMes = ordenaMes(fornecedores_total)
urgenciaMes = ordenaMes(urgenciaTotalFormatada)


######################################################################

valores = []

pyautogui.sleep(5)

#Definando TOP:
pyautogui.sleep(3)
pyautogui.click(570,174)
pyautogui.sleep(3)
pyautogui.click(511,241)
pyautogui.sleep(3)
pyautogui.typewrite("109")
pyautogui.sleep(3)
pyautogui.press('\n')
pyautogui.sleep(3)
pyautogui.click(616,300)
pyautogui.click(616,300)
pyautogui.sleep(10)

#Alterando Tela:
pyautogui.click(1896,92)
pyautogui.sleep(1)
pyautogui.click(1635,409)
pyautogui.sleep(1)
pyautogui.click(568,477)
pyautogui.sleep(1)
pyautogui.click(1299,719)
pyautogui.sleep(30)

pyautogui.sleep(15)


for codLoja,CodFornecedor,codChegada,codItem,quantidade,urgencia in zip(codLojaMes,codFornecedorMes,codChegadaMes,codPorMes,quantidadeMes,urgenciaMes):
    
    if codLoja and CodFornecedor and codChegada and codItem and quantidade:
        dados = {'Loja':codLoja, 
              'Fornecedor':CodFornecedor,
              'Chegada':codChegada,
              'Item':codItem,
              'Quantidade':quantidade,
                 'Urgencia':urgencia}
        
        df = pd.DataFrame(dados)
        
        print(df)
        
        print("-" * 30)  # Separador visual             
        
        # Simula um tempo de atualização antes de substituir os dados
        #time.sleep(2)

        
        fornecedoresUnicos = df["Fornecedor"].unique()
        
        #####################################
        c = 0

        
        if c == 0:
            
            #Inserindo Loja: 
            pyautogui.sleep(4)
            pyautogui.click(300,232)
            pyautogui.sleep(2)  
            pyautogui.sleep(2) 
            pyautogui.write(f"{row.Loja}\n")
            pyautogui.sleep(5)
            #pyautogui.press('\n')

            #Inserindo Parceiro: 
            pyautogui.sleep(4)
            pyautogui.click(302,322)
            pyautogui.sleep(2)  
            #pyautogui.click(442,311)
            pyautogui.sleep(2) 
            pyautogui.write(f"{row.Fornecedor}\n")
            pyautogui.sleep(5)
            pyautogui.press('\n')
            #pyautogui.click(2566,412)
            #pyautogui.click(2566,412)

            #PREV. CHEGADA
            pyautogui.sleep(1)
            pyautogui.click(332,383)
            pyautogui.click(332,383)
            pyautogui.sleep(1)

            pyautogui.typewrite("01/")
            pyautogui.sleep(1)
            pyautogui.typewrite(f"{row.Chegada}\n") 
            pyautogui.sleep(1)
            pyautogui.typewrite("/2025")
            pyautogui.sleep(1)


            #PRONTO FABRICA
            data_atual = datetime.date.today()
            data_nova = data_atual + datetime.timedelta(days=60)
            data_atual_formatada = data_atual.strftime("%d/%m/%Y")
            data_nova_formatada = data_nova.strftime("%d/%m/%Y")
            pyautogui.sleep(1)
            pyautogui.click(344,415)
            pyautogui.sleep(1)
            pyautogui.typewrite(str(data_nova_formatada))

            #DEFININDO MOEDA
            pyautogui.sleep(2)
            pyautogui.click(650,507)
            pyautogui.sleep(15)
            pyautogui.click(615,411)
            pyautogui.sleep(2)
            pyautogui.click(1427,903)

            #COMPRADOR
            pyautogui.sleep(2)
            pyautogui.click(309,572)
            pyautogui.sleep(2)
            pyautogui.typewrite("232")

            #TIPO DE TRANSPORTE
            pyautogui.sleep(2)
            pyautogui.click(631,696)
            pyautogui.sleep(3)
            #pyautogui.press('\n')
            pyautogui.click(291,753)


            #CONFIRMA
            pyautogui.sleep(2)
            pyautogui.click(95,140)
            pyautogui.sleep(4)

            #EXCLUINDO ITEM ADICIONADO AUTOMATICAMENTE
            pyautogui.click(941,354)
            pyautogui.sleep(4)

            #NOVO ITEM
            pyautogui.click(835,352)
            pyautogui.sleep(2)

            pyautogui.sleep(8)
                    
            c += 1 # Provavelmente vai dar erro nesse contador.

        else:
                
            #Inserindo Loja: 
            pyautogui.sleep(4)
            pyautogui.click(320,266)
            pyautogui.sleep(2)  
            pyautogui.sleep(2)
            pyautogui.write(f"{row.Loja}\n")
            pyautogui.sleep(5)
            #pyautogui.press('\n')

            #Inserindo Parceiro: 
            pyautogui.sleep(4)
            pyautogui.click(301,359)
            pyautogui.sleep(2)  
            #pyautogui.click(442,311)
            pyautogui.sleep(2) 
            pyautogui.write(f"{row.Fornecedor}\n")
            pyautogui.sleep(5)
            pyautogui.press('\n')
            #pyautogui.click(2566,412)
            #pyautogui.click(2566,412)

            #PREV. CHEGADA
            pyautogui.sleep(1)
            pyautogui.click(329,421)
            pyautogui.click(329,421)
            pyautogui.sleep(1)
            pyautogui.typewrite("01/")
            pyautogui.sleep(1)
            pyautogui.typewrite(f"{row.Chegada}\n")
            pyautogui.sleep(1)
            pyautogui.typewrite("/2025")
            pyautogui.sleep(1)

            #PRONTO FABRICA
            data_atual = datetime.date.today()
            data_nova = data_atual + datetime.timedelta(days=60)
            data_atual_formatada = data_atual.strftime("%d/%m/%Y")
            data_nova_formatada = data_nova.strftime("%d/%m/%Y")
            pyautogui.sleep(1)
            pyautogui.click(330,448)
            pyautogui.sleep(1)
            pyautogui.typewrite(str(data_nova_formatada))

            #DEFININDO MOEDA
            pyautogui.sleep(2)
            pyautogui.click(648,540)
            pyautogui.sleep(15)
            pyautogui.click(628,414)
            pyautogui.sleep(2)
            pyautogui.click(1428,910)

            #COMPRADOR
            pyautogui.sleep(2)
            pyautogui.click(340,609)
            pyautogui.sleep(2)
            pyautogui.typewrite("232")

            #TIPO DE TRANSPORTE
            #pyautogui.sleep(2)
            #pyautogui.click(631,696)
            #pyautogui.sleep(3)
            #pyautogui.press('\n')
            #pyautogui.click(291,753)


            #CONFIRMA
            pyautogui.sleep(2)
            pyautogui.click(95,140)
            pyautogui.sleep(3)

            #EXCLUINDO ITEM ADICIONADO AUTOMATICAMENTE
            pyautogui.click(891,354)
            pyautogui.sleep(3)

            #NOVO ITEM
            pyautogui.click(835,352)
            pyautogui.sleep(2)

            pyautogui.sleep(8)

            print(fornecedores[c])
        
        ##########################################
        
        for fornecedor in fornecedoresUnicos:
            
            df_fornecedor = df[df["Fornecedor"] == fornecedor]
            print(f"Fornecedor {fornecedor}:")
            print(df_fornecedor)
            print("-" * 40)
                               
            c = 0
            
            x_cod = 783
            y_cod = 419

            x_qtd = 918
            y_qtd = 419

            x_cod_Limite_Tela = 777
            y_cod_Limite_Tela = 610

            x_qtd_Limite_Tela = 915
            y_qtd_Limite_Tela = 608

            repeticao = 0
            Soma_Quatidades = 0
        
            for row in df_fornecedor.itertuples(index=True, name="Linha"):
                
                if repeticao < 8:
                    
                    #Inserindo Código:
                    pyautogui.click(x_cod,y_cod)
                    pyautogui.sleep(1)
                    pyautogui.click(x_cod,y_cod)
                    pyautogui.sleep(4)
                    pyautogui.write(f"{row.Item}\n")
                    pyautogui.sleep(3)

                    #Inserindo Quantidade:
                    pyautogui.click(x_qtd,y_qtd)
                    pyautogui.sleep(3)
                    pyautogui.write(f"{row.Quantidade}\n")
                    pyautogui.sleep(3)

                    #Confirmando Item:
                    pyautogui.click(847,349)
                    pyautogui.click(847,349)
                    pyautogui.sleep(8)

                    #Novo Item
                    pyautogui.click(833,351)
                    pyautogui.sleep(2)

                    #Soma dos valores nas coordenadas para que que o mouse realize o deslocamento para o próximo 
                    #campo na proxima repetição.

                    y_cod += 25
                    y_qtd += 25


                    repeticao += 1

                else: 
                    
                    #Inserindo Código:
                    pyautogui.click(x_cod_Limite_Tela,y_cod_Limite_Tela)
                    pyautogui.sleep(1)
                    pyautogui.click(x_cod_Limite_Tela,y_cod_Limite_Tela)
                    pyautogui.sleep(3) 
                    pyautogui.write(f"{row.Item}\n")
                    pyautogui.sleep(3)

                    #Inserindo Quantidade:
                    pyautogui.click(x_qtd_Limite_Tela,y_qtd_Limite_Tela)
                    pyautogui.sleep(3)
                    pyautogui.write(f"{row.Quantidade}\n")
                    pyautogui.sleep(3)

                    #Confirmando Item:
                    pyautogui.click(847,349)
                    pyautogui.click(847,349)
                    pyautogui.sleep(8)

                    #Novo Item
                    pyautogui.click(833,351)
                    pyautogui.sleep(2)

                    Soma_Quatidades += quantidades[i]


                #Novo pedido
                pyautogui.click(944,350)
                pyautogui.sleep(2)
                pyautogui.click(97,144)

                #Definando TOP:
                pyautogui.sleep(3)
                pyautogui.click(333,483)
                pyautogui.sleep(3)
                pyautogui.typewrite("109")
                pyautogui.sleep(3)
            
                
                #################################################
                

                print(f"Linha {row.Index}:")
                
                print(f"Loja: {row.Loja}")
                
                print(f"Fornecedor: {row.Fornecedor}")
                
                print(f"Chegada: {row.Chegada}")
                
                print(f"Item: {row.Item}")
                
                print(f"Quantidade: {row.Quantidade}")
                print("-" * 30)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 import datetime
# ----> 2 import pyautogui
#       3 import pandas as pd
#       5 df = pd.read_excel('JUNBO HDS MATRIZ - DIG.xlsx')
#
# ModuleNotFoundError: No module named 'pyautogui'
